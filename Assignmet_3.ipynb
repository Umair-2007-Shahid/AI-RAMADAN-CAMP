# %%
# Question 1

n1= float(input("Enter first number: "))
n2= float(input("Enter second number: "))

print("Choose operation:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

choice = input("Enter choice (1-5): ")

if choice == '1':
    print("Result:", n1 + n2)

elif choice == '2':
    print("Result:", n1 - n2)

elif choice == '3':
    print("Result:", n1 * n2)

elif choice == '4':
    if n2 != 0:
        print("Result:", n1 / n2)
    else:
        print("Cannot divide by zero")

elif choice == '5':
    print("Result:", n1 ** n2)

else:
    print("Invalid choice")
# Out:
# Enter first number:  5
# Enter second number:  3
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Enter choice (1-5):  5
# Result: 125.0

# %%
#question 2

my_list = [1, "apple", "banana", 3.5]

for item in my_list:
    if type(item) == int or type(item) == float:
        print("Numeric value found")
        break
else:
    print("No numeric value found")
# Out:
# Numeric value found

# %%
#Question 3

a_dict = {'name': 'Ali', 'age': 20}

a_dict['city'] = 'Karachi'

print("Updated Dictionary:", a_dict)
# Out:
# Updated Dictionary: {'name': 'Ali', 'age': 20, 'city': 'Karachi'}

# %%
#Question 4

a_dict = {'x': 30, 'y': 20, 'z': 40}

total = 0
for value in a_dict.values():
    if type(value) == int or type(value) == float:
        total = total + value

print("Sum is:", total)
# Out:
# Sum is: 90

# %%
#Question 5

a_list = [1, 2, 3, 4, 2, 5, 1, 6]

duplicates = []

for item in a_list:
    if a_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]

# %%
#Question 6

a_dict = {'season': 'summer', 'price': 200, 'city': 'Karachi'}

key_to_check = input("Enter key to check: ")

if key_to_check in a_dict:
    print("Key exists in dictionary")
else:
    print("Key does not exist")
# Out:
# Enter key to check:  summer
# Key does not exist
